# %%
import os

# Sur Windows, on utilise juste le nom du dossier si le terminal est ouvert au bon endroit
dossier_test = 'dataset_final/glass'

print("Contenu BRUT du dossier glass :")
if os.path.exists(dossier_test):
    tout_contenu = os.listdir(dossier_test)
    print(f"Nombre d'éléments trouvés : {len(tout_contenu)}")
    
    for fichier in tout_contenu[:10]: # Affiche les 10 premiers
        print(f" - {fichier}")
        
    if len(tout_contenu) == 0:
        print("-> Le dossier est VIDE.")
else:
    print("-> Erreur : Le chemin n'existe pas !")
    print("Assure-toi que ton terminal VS Code est bien ouvert dans le dossier 'garbage_classification'")
